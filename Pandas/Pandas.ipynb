# %% [markdown]
# # Pandas
#
# ##### Author : Chintamani Madhukar Kasture

# %%
import pandas as pd

# %%
pd.DataFrame({'Chinta':['I liked that','I didnt like that'],
             'Aniket':['Pretty Good','Bad']},
            index = ['Prod_1','Prod_2'])
# Out:
#                    Chinta       Aniket
# Prod_1       I liked that  Pretty Good
# Prod_2  I didnt like that          Bad

# %%
pd.Series([10,20,30],index=['2015_Sales','2016_Sales','2017_Sales'],name='Prod_1')
# Out:
# 2015_Sales    10
# 2016_Sales    20
# 2017_Sales    30
# Name: Prod_1, dtype: int64

# %%
wine = pd.read_csv('wine_data.csv',index_col=0)

# %%
wine.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
wine.shape
# Out:
# (150930, 10)

# %%
wine.country
# Out:
# 0             US
# 1          Spain
# 2             US
# 3             US
# 4         France
#            ...
# 150925     Italy
# 150926    France
# 150927     Italy
# 150928    France
# 150929     Italy
# Name: country, Length: 150930, dtype: object

# %%
wine['country'][0]
# Out:
# 'US'

# %%
wine.iloc[0]
# Out:
# country                                                       US
# description    This tremendous 100% varietal wine hails from ...
# designation                                    Martha's Vineyard
# points                                                        96
# price                                                        235
# province                                              California
# region_1                                             Napa Valley
# region_2                                                    Napa
# variety                                       Cabernet Sauvignon
# winery                                                     Heitz
# Name: 0, dtype: object

# %%
wine.iloc[:,[0,1,2,3]]
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points
# 0                          Martha's Vineyard      96
# 1       Carodorum Selección Especial Reserva      96
# ...

# %%
wine.iloc[0:3,0]
# Out:
# 0       US
# 1    Spain
# 2       US
# Name: country, dtype: object

# %%
wine.loc[(wine.country == 'Italy') & (wine.points == 95)]
# Out:
#        country                                        description  \
# 10       Italy  Elegance, complexity and structure come togeth...
# 2741     Italy  Here's a delicious red that opens with appeali...
# 2747     Italy  Forest floor, aromatic herb, dark spice and eu...
# 2748     Italy  Forest floor, wild berry, new leather and bals...
# 2749     Italy  Truffle, leather, forest floor, pipe tobacco a...
# ...        ...                                                ...
# 135148   Italy  Sicilians are notorious for an insatiable swee...
# 137388   Italy  With its extraordinary texture, bright persona...
# 138924   Italy  Enthusiastic applause across the panel for thi...
# 139144   Italy  This is a fabulous late harvest tour de force ...
# 139146   Italy  A liquid lullaby more than a wine, this Brunel...
#
#                                  designation  points  price  \
# 10                        Ronco della Chiesa      95   80.0
# ...

# %%
wine.loc[(wine.country == 'Italy') |(wine.points == 95)]
# Out:
#        country                                        description  \
# 4       France  This is the top wine from La Bégude, named aft...
# 5        Spain  Deep, dense and pure from the opening bell, th...
# 6        Spain  Slightly gritty black-fruit aromas include a s...
# 7        Spain  Lush cedary black-fruit aromas are luxe and of...
# 8           US  This re-named vineyard was formerly bottled as...
# ...        ...                                                ...
# 150920   Italy  Rich and mature aromas of smoke, earth and her...
# 150922   Italy  Made by 30-ish Roberta Borghese high above Man...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                     designation  points  price            province  \
# 4                    La Brûlade      95   66.0            Provence
# ...

# %%
wine.points.describe()
# Out:
# count    150930.000000
# mean         87.888418
# std           3.222392
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          90.000000
# max         100.000000
# Name: points, dtype: float64

# %%
wine.describe()
# Out:
#               points          price
# count  150930.000000  137235.000000
# mean       87.888418      33.131482
# std         3.222392      36.322536
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %%
wine.points.mean()
# Out:
# 87.8884184721394

# %%
wine.points.median()
# Out:
# 88.0

# %%
wine.country+'-'+wine.region_1
# Out:
# 0                  US-Napa Valley
# 1                      Spain-Toro
# 2               US-Knights Valley
# 3            US-Willamette Valley
# 4                   France-Bandol
#                    ...
# 150925    Italy-Fiano di Avellino
# 150926           France-Champagne
# 150927    Italy-Fiano di Avellino
# 150928           France-Champagne
# 150929           Italy-Alto Adige
# Length: 150930, dtype: object

# %%
wine.groupby('points').points.count()
# Out:
# points
# 80       898
# 81      1502
# 82      4041
# 83      6048
# 84     10708
# 85     12411
# 86     15573
# 87     20747
# 88     17871
# 89     12921
# 90     15973
# 91     10536
# 92      9241
# 93      6017
# 94      3462
# 95      1716
# 96       695
# 97       365
# 98       131
# 99        50
# 100       24
# Name: points, dtype: int64

# %%
wine.groupby('points').points.min()
# Out:
# points
# 80      80
# 81      81
# 82      82
# 83      83
# 84      84
# 85      85
# 86      86
# 87      87
# 88      88
# 89      89
# 90      90
# 91      91
# 92      92
# 93      93
# 94      94
# 95      95
# 96      96
# 97      97
# 98      98
# 99      99
# 100    100
# Name: points, dtype: int64

# %%
wine.groupby(['country']).price.agg([len,min,max])
# Out:
#                             len   min     max
# country
# Albania                     2.0  20.0    20.0
# Argentina                5631.0   4.0   250.0
# Australia                4957.0   5.0   850.0
# Austria                  3057.0   8.0  1100.0
# Bosnia and Herzegovina      4.0  12.0    13.0
# Brazil                     25.0  11.0    35.0
# Bulgaria                   77.0   7.0    28.0
# Canada                    196.0  12.0   145.0
# Chile                    5816.0   5.0   400.0
# China                       3.0   7.0    27.0
# Croatia                    89.0  12.0    65.0
# Cyprus                     31.0  10.0    22.0
# Czech Republic              6.0  15.0    25.0
# Egypt                       3.0   NaN     NaN
# England                     9.0  38.0    75.0
# France                  21098.0   5.0  2300.0
# Georgia                    43.0   9.0    40.0
# Germany                  2452.0   5.0   775.0
# Greece                    884.0   7.0   120.0
# ...

# %%
wine_reviews = wine.reset_index()

# %%
wine_reviews.sort_values(by=['country','points'])
# Out:
#          index    country                                        description  \
# 4642      4642    Albania  This garnet-colored wine made from 100% Kallme...
# 4864      4864    Albania  This garnet-colored wine made from 100% Kallme...
# 7793      7793  Argentina  Tropical, soapy aromas are yeasty and flat. Fl...
# 7794      7794  Argentina  Candied plum and red berry aromas smell like r...
# 10533    10533  Argentina  Oily, match-stick aromas are none too friendly...
# ...        ...        ...                                                ...
# 68226    68226        NaN  From first sniff to last, the nose never makes...
# 113016  113016        NaN  From first sniff to last, the nose never makes...
# 135696  135696        NaN  From first sniff to last, the nose never makes...
# 1133      1133        NaN  Delicate white flowers and a spin of lemon pee...
# 1440      1440        NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
#
# ...

# %%
wine.dtypes
# Out:
# country         object
# description     object
# designation     object
# points           int64
# price          float64
# province        object
# region_1        object
# region_2        object
# variety         object
# winery          object
# dtype: object

# %%
wine.points.dtype
# Out:
# dtype('int64')

# %%
wine[pd.isnull(wine.country)]
# Out:
#        country                                        description  \
# 1133       NaN  Delicate white flowers and a spin of lemon pee...
# 1440       NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 68226      NaN  From first sniff to last, the nose never makes...
# 113016     NaN  From first sniff to last, the nose never makes...
# 135696     NaN  From first sniff to last, the nose never makes...
#
#          designation  points  price province region_1 region_2     variety  \
# 1133       Askitikos      90   17.0      NaN      NaN      NaN   Assyrtiko
# 1440            Shah      90   30.0      NaN      NaN      NaN   Red Blend
# 68226   Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 113016  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 135696  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
#
#            winery
# 1133     Tsililis
# 1440    Büyülübağ
# 68226     Chilcas
# 113016    Chilcas
# 135696    Chilcas

# %%
wine.region_2.fillna('ABC')
# Out:
# 0                      Napa
# 1                       ABC
# 2                    Sonoma
# 3         Willamette Valley
# 4                       ABC
#                 ...
# 150925                  ABC
# 150926                  ABC
# 150927                  ABC
# 150928                  ABC
# 150929                  ABC
# Name: region_2, Length: 150930, dtype: object

# %%
wine.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
wine.province.replace('California','Califoornia')
# Out:
# 0                Califoornia
# 1             Northern Spain
# 2                Califoornia
# 3                     Oregon
# 4                   Provence
#                  ...
# 150925        Southern Italy
# 150926             Champagne
# 150927        Southern Italy
# 150928             Champagne
# 150929    Northeastern Italy
# Name: province, Length: 150930, dtype: object

# %%
wine.rename(columns={'points':'score'})
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  score  price  \
# 0                          Martha's Vineyard     96  235.0
# ...
